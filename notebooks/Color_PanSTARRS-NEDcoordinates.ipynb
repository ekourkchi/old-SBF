# %% [markdown]
# ## PanSTARRS $(g-z)$ analysis
# Version 08 Sep 2023, J. Jensen + E. Kourkchi
#
# Retrieve a standard 3000 pixel frame with the galaxy at the center in g and z. Get the exposure time from the header. Get the extinction values from NED.
#
# To get the background subtraction right, mask off the main galaxy and look at the residual well away from the galaxy (much larger FOV than WFC3/IR).
#
# Run SExtractor to identify stars and other objects, and make a mask automatically. elliprof is used to remove the galaxy prior to running SExtractor.
#
# You still have to edit those masks manually because PS images typically have lines and edges crossing the brighter galaxies and I don’t want weird color discontinuities. This is the only manual step--editing the masks to take out lines.
#
# Generate the $(g-z)$ color map by subtracting sky, dividing by exposure time, calculating $-2.5\log f$, correcting for extinction, and subtracting to get $(g-z)$.
#
# The last step is to use monsta “fluc mask” command to make the elliptical annuli in the same sizes as the SBF analysis and write the median and average values to a text file.

# %% [markdown]
# ## Installing Required Python Packages
#
# Note: run the following cell once.

# %%
import sys, os
 
# path of the pysbf folder
# sys.path.insert(0, os.getcwd()+"/../../")
 
pysbf_path = "/media/Data/Home/PanStarrs/Jan/HI/augment/SBF/codes/"
sys.path.insert(0, pysbf_path)
from pysbf import *
 
configFolder = pysbf_path + "pysbf/config/sextractor/"

# %% [markdown]
# ## Object Initialization

# %%
# galaxy_root is where the WFC3/IR data are located; PS_root is where the PanSTARRS g,z data are located.
galaxy_root = '/home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/'
PS_root = '/home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/'

# %%
# This is the radial region to fit with elliprof.
# Values around 80 are good for small galaxies, 100 for larger ones.
#name = "c328014"; NR=str(80)
#name = "c539126"; NR=str(80)
#name = "c540079"; NR=str(80)
#name = "e436045"; NR=str(80)
#name = "e461007"; NR=str(80)
#name = "e462015"; NR=str(80)
#name = "e507025"; NR=str(100)
#name = "ic5193"; NR=str(100)
#name = "n0080"; NR=str(100)
#name = "n0380"; NR=str(100)
#name = "n0679"; NR=str(100)
#name = "n0750"; NR=str(100)
#name = "n2208"; NR=str(100)
#name = "n2256"; NR=str(100)
#name = "n2329"; NR=str(100)
#name = "n2418"; NR=str(100)
#name = "n2569"; NR=str(100)
#name = "n3070"; NR=str(100)
#name = "n3091"; NR=str(100)
#name = "n3308"; NR=str(100)
#name = "n3311"; NR=str(100)
#name = "n4825"; NR=str(100)
#name = "n4955"; NR=str(100)
#name = "n6223"; NR=str(100)
#name = "n6577"; NR=str(80)
#name = "n6688"; NR=str(70)
#name = "n6968"; NR=str(100)
#name = "n7265"; NR=str(100)
#name = "n7274"; NR=str(100)
#name = "n7426"; NR=str(80)
#name = "n7618"; NR=str(100)
#name = "p158229"; NR=str(80)
#name = "p170207"; NR=str(80)
#name = "u03353"; NR=str(100)
#name = "u03396"; NR=str(90)
#name = "u11990"; NR=str(100)
# name = "u12517"; NR=str(100)

name = "n7265"; NR=str(100)

# %% [markdown]
# ### Galaxy Name
#
# You can enter galaxy name in a foramt that is recognized ny NED. The coordinates and other info are autmatically extracted from NED.
#
# `reference`: http://ned.ipac.caltech.edu/forms/gmd.html

# %%
ned = get_ned_info([name])
if ned is not None:
    ra, dec = ned.iloc[0]["ra_dec"]
ned
# Out:
#       Row Input Object Name Object Name            RA           Dec     Gal  \
# N7265   1             N7265    NGC 7265  22h22m27.44s  +36d12m34.6s  92.115
#
#            Gal Extinction Row                                    ra_dec
# N7265  -17.594      0.489   1  (335.61433333333326, 36.209611111111116)

# %%
outFolder = PS_root + name + '/PS_Outputs_' + name + '/'
createDir(outFolder)

g_fits = PS_root + name + '/' + name + 'g.fits'
z_fits = PS_root + name + '/' + name + 'z.fits'
    
PS_mask = PS_root + name + '/' + name + '.mask'
if not os.path.exists(PS_mask):
    PS_mask = outFolder + '/' + name + '.mask' 
PS_lines = PS_root + name + '/' + name + 'ps.mask'
PS_skymask = configFolder + 'pssky.mask'
PS_circlemask = configFolder + 'pscircle.mask'

print("PS files: ", g_fits, '  ', z_fits)

print("RA [deg]: ",  ra)
print("Dec [deg]: ", dec)

size = 3000   # size in pixels (0.25 arcsec/pixel)

gim = getgrayim(ra,dec,size=size,filter="g")
zim = getgrayim(ra,dec,size=size,filter="z")

pylab.rcParams.update({'font.size':12})
pylab.figure(1,(12,6))

pylab.subplot(121)
pylab.imshow(gim,origin="upper", cmap='gray')
pylab.title(name + ' PS1 (g)')

pylab.subplot(122)
pylab.title(name + ' PS1 (z)')
pylab.imshow(zim,origin="upper", cmap='gray')
# Out:
# PS files:  /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/n7265g.fits    /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/n7265z.fits
# RA [deg]:  335.61433333333326
# Dec [deg]:  36.209611111111116

# %% [markdown]
# ### Looking up NED for Galaxtic Extinctions
#
# Here, all we need is to have the coordinates of the galaxy

# %%
df_extinction = get_extinction(ra, dec)
df_extinction.set_index("Bandpass", inplace=True)

PS1_rows = [band for band in df_extinction.index.values if "PS1" in band]

df_extinction.loc[PS1_rows]
# Out:
#           Central Wavelength  The Galactic extinction  \
# Bandpass
# PS1 g                   0.49                    0.376
# PS1 r                   0.62                    0.269
# PS1 i                   0.75                    0.199
# PS1 z                   0.87                    0.157
# PS1 y                   0.97                    0.129
# PS1 w                   0.62                    0.278
#
#          Refcode of the publications
# Bandpass
# PS1 g            2011ApJ...737..103S
# PS1 r            2011ApJ...737..103S
# PS1 i            2011ApJ...737..103S
# PS1 z            2011ApJ...737..103S
# PS1 y            2011ApJ...737..103S
# PS1 w            2011ApJ...737..103S

# %%
extinctions = df_extinction["The Galactic extinction"]

gext = extinctions["PS1 g"]
zext = extinctions["PS1 z"]

print("Galactic Extinction (PS1 g): ", gext)
print("Galactic Extinction (PS1 z): ", zext)
# Out:
# Galactic Extinction (PS1 g):  0.376
# Galactic Extinction (PS1 z):  0.157

# %% [markdown]
# ### Downloading PS1 files if they don't already exist

# %%
## downloading PS1 fits files 
def download_PS1(ra, dec, size, filter='g', format='fits', outFits="PS1.fits"):

    fitsurl = geturl(ra, dec, size=int(size), filters=filter, format=format)
    xcmd("curl '"+fitsurl[0]+"' -o "+outFits, verbose=False)
    print('Downloaded ... ' + outFits)

# %%
# if the original PS1 files do not exist, download them directly and use them
if not os.path.exists(g_fits):
    print('Could not find '+g_fits+'\n Downloading ...')
    g_fits = outFolder+"/"+name+"_g.fits"
    download_PS1(ra, dec, size, filter='g', outFits=g_fits)
if not os.path.exists(z_fits):
    print('Could not find '+z_fits+'\n Downloading ...')
    z_fits = outFolder+"/"+name+"_z.fits"
    download_PS1(ra, dec, size, filter='z', outFits=z_fits)

print("g-band fits file: " + g_fits)
print("z-band fits file: " + z_fits)

hdul = fits.open(g_fits)
hdr = hdul[0].header     # header
gexp = hdr["EXPTIME"]

hdul = fits.open(z_fits)
hdr = hdul[0].header     # header
zexp = hdr["EXPTIME"]

print("g-band exposure time (sec): " + str(gexp))
print("z-band exposure time (sec): " + str(zexp))
# Out:
# Could not find /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/n7265g.fits
#  Downloading ...
# Downloaded ... /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265//n7265_g.fits
# Could not find /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/n7265z.fits
#  Downloading ...
# Downloaded ... /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265//n7265_z.fits
# g-band fits file: /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265//n7265_g.fits
# z-band fits file: /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265//n7265_z.fits
# g-band exposure time (sec): 860.0
# z-band exposure time (sec): 870.0

# %% [markdown]
# ## Mask and residual image section
#
# This next block is for making PanSTARRS masks using Source Extractor.
# But these masks are always insufficient because they do not take out the stripes and defects.
# They should be manually edited. Please edit the mask and rerun.

# %%
# create residual images for Source Extractor
monsta_script = """
    rd 1 '"""+g_fits+"""'
    rd 2 '"""+z_fits+"""'
    clip 1 nan=0
    clip 2 nan=0
    wd 1 '"""+outFolder+name+"""g.nonan'
    wd 2 '"""+outFolder+name+"""z.nonan'
    set nr="""+NR+"""/10$nint
    string nr '%i2.0' nr
    cop 3 1
    cop 4 2
    elliprof 3 model rmstar x0=1500 y0=1500 r0=7 r1="""+NR+""" nr=nr niter=5
    elliprof 4 model rmstar x0=1500 y0=1500 r0=7 r1="""+NR+""" nr=nr niter=5
    cop 5 1
    si 5 3
    cop 6 2
    si 6 4
    wd 5 '"""+outFolder+name+"""g.resid'
    wd 6 '"""+outFolder+name+"""z.resid'
    rd 10 '"""+PS_circlemask+"""'
    ac 5 500.
    ac 6 500.
    mi 5 10
    mi 6 10
    box 1 nc=550 nr=550 cc=1500 cr=1500
    wind 5 box=1
    wind 6 box=1
    wd 5 '"""+outFolder+name+"""g.zoom.resid'
    wd 6 '"""+outFolder+name+"""z.zoom.resid'
"""
run_monsta(monsta_script, 'monsta.pro', 'monsta.log')
# Out:
# 'OK'

# %%
# Run Source Extractor if needed to generate the mask.
monsta_script = """
    rd 7 '"""+outFolder+"""/psg.obj'
    rd 8 '"""+outFolder+"""/psz.obj'
    di 7 7
    di 8 8
    mi 8 7
    wd 8 '"""+outFolder+name+""".mask' bitmap
"""
sestring_g = outFolder+name+'g.resid -c '+configFolder+'psg.inpar -CATALOG_NAME '+outFolder+'psg.cat -PARAMETERS_NAME '+configFolder+'sbf.param -FILTER_NAME '+configFolder+'gauss_2.0_5x5.conv -STARNNW_NAME '+configFolder+'default.nnw -CHECKIMAGE_NAME '+outFolder+'psg.obj'
sestring_z = outFolder+name+'z.resid -c '+configFolder+'psz.inpar -CATALOG_NAME '+outFolder+'psz.cat -PARAMETERS_NAME '+configFolder+'sbf.param -FILTER_NAME '+configFolder+'gauss_2.0_5x5.conv -STARNNW_NAME '+configFolder+'default.nnw -CHECKIMAGE_NAME '+outFolder+'psz.obj'
# print(sestring_g)
# print(sestring_z)

if not os.path.exists(PS_mask):
    print('Could not find '+PS_mask)
    PS_mask = outFolder + name + '.mask'
    print('Making ' + PS_mask + ' now. Please edit it before proceeding.')
    ! sex {sestring_g}
    ! sex {sestring_z}
#    % sex """+outFolder+name+"""g.resid -c """+configFolder+"""psg.inpar -CATALOG_NAME """+outFolder+"""/psg.cat -CHECKIMAGE_NAME """+outFolder+"""/psg.obj
#    % sex """+outFolder+name+"""g.resid -c """+configFolder+"""psz.inpar -CATALOG_NAME """+outFolder+"""/psz.cat -CHECKIMAGE_NAME """+outFolder+"""/psz.obj
    run_monsta(monsta_script, 'monsta.pro', 'monsta.log')
# Out:
# Could not find /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265//n7265.mask
# Making /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265/n7265.mask now. Please edit it before proceeding.
# >
# ----- SExtractor 2.8.6 started on 2023-09-08 at 13:21:47 with 8 threads
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for n7265g.resid
# Measuring from: "Unnamed"  / 3000 x 3000 / 0 bits FLOATING POINT data
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   40
# > Setting up background map at line:   80
# > Setting up background map at line:  120
# > Setting up background map at line:  160
# > Setting up background map at line:  200
# > Setting up background map at line:  240
# > Setting up background map at line:  280
# > Setting up background map at line:  320
# > Setting up background map at line:  360
# > Setting up background map at line:  400
# > Setting up background map at line:  440
# > Setting up background map at line:  480
# > Setting up background map at line:  520
# > Setting up background map at line:  560
# > Setting up background map at line:  600
# > Setting up background map at line:  640
# > Setting up background map at line:  680
# > Setting up background map at line:  720
# > Setting up background map at line:  760
# > Setting up background map at line:  800
# > Setting up background map at line:  840
# > Setting up background map at line:  880
# > Setting up background map at line:  920
# > Setting up background map at line:  960
# > Setting up background map at line: 1000
# > Setting up background map at line: 1040
# > Setting up background map at line: 1080
# > Setting up background map at line: 1120
# > Setting up background map at line: 1160
# > Setting up background map at line: 1200
# > Setting up background map at line: 1240
# > Setting up background map at line: 1280
# > Setting up background map at line: 1320
# > Setting up background map at line: 1360
# > Setting up background map at line: 1400
# > Setting up background map at line: 1440
# > Setting up background map at line: 1480
# > Setting up background map at line: 1520
# > Setting up background map at line: 1560
# > Setting up background map at line: 1600
# > Setting up background map at line: 1640
# > Setting up background map at line: 1680
# > Setting up background map at line: 1720
# > Setting up background map at line: 1760
# > Setting up background map at line: 1800
# > Setting up background map at line: 1840
# > Setting up background map at line: 1880
# > Setting up background map at line: 1920
# > Setting up background map at line: 1960
# > Setting up background map at line: 2000
# > Setting up background map at line: 2040
# > Setting up background map at line: 2080
# > Setting up background map at line: 2120
# > Setting up background map at line: 2160
# > Setting up background map at line: 2200
# > Setting up background map at line: 2240
# > Setting up background map at line: 2280
# > Setting up background map at line: 2320
# > Setting up background map at line: 2360
# > Setting up background map at line: 2400
# > Setting up background map at line: 2440
# > Setting up background map at line: 2480
# > Setting up background map at line: 2520
# > Setting up background map at line: 2560
# > Setting up background map at line: 2600
# > Setting up background map at line: 2640
# > Setting up background map at line: 2680
# > Setting up background map at line: 2720
# > Setting up background map at line: 2760
# > Setting up background map at line: 2800
# > Setting up background map at line: 2840
# > Setting up background map at line: 2880
# > Setting up background map at line: 2920
# > Setting up background map at line: 2960
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: -6.71361   RMS: 76.6173    / Threshold: 153.235
# > Scanning image
# > Line:   16  Objects:        3 detected /        0 sextracted
# > Line:   32  Objects:       12 detected /        0 sextracted
# > Line:   48  Objects:       18 detected /        0 sextracted
# > Line:   64  Objects:       24 detected /        0 sextracted
# > Line:   80  Objects:       31 detected /        0 sextracted
# > Line:   96  Objects:       40 detected /        0 sextracted
# > Line:  112  Objects:       46 detected /        0 sextracted
# > Line:  128  Objects:       49 detected /        0 sextracted
# > Line:  144  Objects:       57 detected /        0 sextracted
# > Line:  160  Objects:       59 detected /        0 sextracted
# > Line:  176  Objects:       60 detected /        0 sextracted
# > Line:  192  Objects:       64 detected /        0 sextracted
# > Line:  208  Objects:       68 detected /        0 sextracted
# > Line:  224  Objects:       74 detected /        0 sextracted
# > Line:  240  Objects:       80 detected /        0 sextracted
# > Line:  256  Objects:       88 detected /        0 sextracted
# > Line:  272  Objects:       96 detected /        0 sextracted
# > Line:  288  Objects:      101 detected /        0 sextracted
# > Line:  304  Objects:      107 detected /        0 sextracted
# > Line:  320  Objects:      112 detected /        0 sextracted
# > Line:  336  Objects:      121 detected /        0 sextracted
# > Line:  352  Objects:      126 detected /        0 sextracted
# > Line:  368  Objects:      134 detected /        0 sextracted
# > Line:  384  Objects:      139 detected /        0 sextracted
# > Line:  400  Objects:      148 detected /        0 sextracted
# > Line:  416  Objects:      153 detected /        0 sextracted
# > Line:  432  Objects:      159 detected /        0 sextracted
# > Line:  448  Objects:      163 detected /        0 sextracted
# > Line:  464  Objects:      176 detected /        0 sextracted
# > Line:  480  Objects:      179 detected /        0 sextracted
# > Line:  496  Objects:      190 detected /        0 sextracted
# > Line:  512  Objects:      192 detected /        0 sextracted
# > Line:  528  Objects:      196 detected /        0 sextracted
# > Line:  544  Objects:      200 detected /        0 sextracted
# > Line:  560  Objects:      210 detected /        0 sextracted
# > Line:  576  Objects:      220 detected /        0 sextracted
# > Line:  592  Objects:      223 detected /        0 sextracted
# > Line:  608  Objects:      226 detected /        0 sextracted
# > Line:  624  Objects:      229 detected /        0 sextracted
# > Line:  640  Objects:      237 detected /        0 sextracted
# > Line:  656  Objects:      244 detected /        0 sextracted
# > Line:  672  Objects:      248 detected /        0 sextracted
# > Line:  688  Objects:      250 detected /        0 sextracted
# > Line:  704  Objects:      256 detected /        0 sextracted
# > Line:  720  Objects:      261 detected /        0 sextracted
# > Line:  736  Objects:      270 detected /        0 sextracted
# > Line:  752  Objects:      277 detected /        0 sextracted
# > Line:  768  Objects:      282 detected /        0 sextracted
# > Line:  784  Objects:      285 detected /        0 sextracted
# > Line:  800  Objects:      290 detected /        0 sextracted
# > Line:  816  Objects:      295 detected /        0 sextracted
# > Line:  832  Objects:      300 detected /        0 sextracted
# > Line:  848  Objects:      304 detected /        0 sextracted
# > Line:  864  Objects:      309 detected /        0 sextracted
# > Line:  880  Objects:      313 detected /        0 sextracted
# > Line:  896  Objects:      322 detected /        0 sextracted
# > Line:  912  Objects:      328 detected /        0 sextracted
# > Line:  928  Objects:      331 detected /        0 sextracted
# > Line:  944  Objects:      338 detected /        0 sextracted
# > Line:  960  Objects:      343 detected /        0 sextracted
# > Line:  976  Objects:      353 detected /        0 sextracted
# > Line:  992  Objects:      365 detected /        0 sextracted
# > Line: 1008  Objects:      373 detected /        0 sextracted
# > Line: 1024  Objects:      386 detected /        0 sextracted
# > Line: 1040  Objects:      393 detected /        0 sextracted
# > Line: 1056  Objects:      401 detected /        0 sextracted
# > Line: 1072  Objects:      406 detected /        0 sextracted
# > Line: 1088  Objects:      415 detected /        0 sextracted
# > Line: 1104  Objects:      428 detected /        0 sextracted
# > Line: 1120  Objects:      435 detected /        0 sextracted
# > Line: 1136  Objects:      439 detected /        0 sextracted
# > Line: 1152  Objects:      449 detected /        0 sextracted
# > Line: 1168  Objects:      455 detected /        0 sextracted
# > Line: 1184  Objects:      459 detected /        0 sextracted
# > Line: 1200  Objects:      469 detected /        0 sextracted
# > Line: 1216  Objects:      477 detected /        0 sextracted
# > Line: 1232  Objects:      490 detected /        0 sextracted
# > Line: 1248  Objects:      501 detected /        0 sextracted
# > Line: 1264  Objects:      510 detected /        0 sextracted
# > Line: 1280  Objects:      521 detected /        0 sextracted
# > Line: 1296  Objects:      524 detected /        0 sextracted
# > Line: 1312  Objects:      530 detected /        0 sextracted
# > Line: 1328  Objects:      539 detected /        0 sextracted
# > Line: 1344  Objects:      549 detected /        0 sextracted
# > Line: 1360  Objects:      552 detected /        0 sextracted
# > Line: 1376  Objects:      562 detected /        0 sextracted
# > Line: 1392  Objects:      566 detected /        0 sextracted
# > Line: 1408  Objects:      578 detected /        0 sextracted
# > Line: 1424  Objects:      584 detected /        0 sextracted
# > Line: 1440  Objects:      587 detected /        0 sextracted
# > Line: 1456  Objects:      591 detected /        0 sextracted
# > Line: 1472  Objects:      601 detected /        0 sextracted
# > Line: 1488  Objects:      608 detected /        0 sextracted
# > Line: 1504  Objects:      622 detected /        0 sextracted
# > Line: 1520  Objects:      628 detected /        0 sextracted
# > Line: 1536  Objects:      642 detected /        0 sextracted
# > Line: 1552  Objects:      647 detected /        0 sextracted
# > Line: 1568  Objects:      653 detected /        0 sextracted
# > Line: 1584  Objects:      670 detected /        0 sextracted
# > Line: 1600  Objects:      677 detected /        0 sextracted
# > Line: 1616  Objects:      689 detected /        0 sextracted
# > Line: 1632  Objects:      703 detected /        0 sextracted
# > Line: 1648  Objects:      716 detected /        0 sextracted
# > Line: 1664  Objects:      723 detected /        0 sextracted
# > Line: 1680  Objects:      728 detected /        0 sextracted
# > Line: 1696  Objects:      739 detected /        0 sextracted
# > Line: 1712  Objects:      746 detected /        0 sextracted
# > Line: 1728  Objects:      757 detected /        0 sextracted
# > Line: 1744  Objects:      760 detected /        0 sextracted
# > Line: 1760  Objects:      764 detected /        0 sextracted
# > Line: 1776  Objects:      775 detected /        0 sextracted
# > Line: 1792  Objects:      786 detected /        0 sextracted
# > Line: 1808  Objects:      792 detected /        0 sextracted
# > Line: 1824  Objects:      796 detected /        0 sextracted
# > Line: 1840  Objects:      805 detected /        0 sextracted
# > Line: 1856  Objects:      814 detected /        0 sextracted
# > Line: 1872  Objects:      819 detected /        0 sextracted
# > Line: 1888  Objects:      831 detected /        0 sextracted
# > Line: 1904  Objects:      835 detected /        0 sextracted
# > Line: 1920  Objects:      841 detected /        0 sextracted
# > Line: 1936  Objects:      849 detected /        0 sextracted
# > Line: 1952  Objects:      854 detected /        0 sextracted
# > Line: 1968  Objects:      862 detected /        0 sextracted
# > Line: 1984  Objects:      870 detected /        0 sextracted
# > Line: 2000  Objects:      883 detected /        0 sextracted
# > Line: 2016  Objects:      889 detected /        0 sextracted
# > Line: 2032  Objects:      897 detected /        0 sextracted
# > Line: 2048  Objects:      909 detected /        0 sextracted
# > Line: 2064  Objects:      919 detected /        0 sextracted
# > Line: 2080  Objects:      920 detected /        0 sextracted
# > Line: 2096  Objects:      925 detected /        0 sextracted
# > Line: 2112  Objects:      934 detected /        0 sextracted
# > Line: 2128  Objects:      944 detected /        0 sextracted
# > Line: 2144  Objects:      950 detected /        0 sextracted
# > Line: 2160  Objects:      952 detected /        0 sextracted
# > Line: 2176  Objects:      955 detected /        0 sextracted
# > Line: 2192  Objects:      967 detected /        0 sextracted
# > Line: 2208  Objects:      976 detected /        0 sextracted
# > Line: 2224  Objects:      988 detected /        0 sextracted
# > Line: 2240  Objects:      992 detected /        0 sextracted
# > Line: 2256  Objects:      999 detected /        0 sextracted
# > Line: 2272  Objects:     1006 detected /        0 sextracted
# > Line: 2288  Objects:     1014 detected /        0 sextracted
# > Line: 2304  Objects:     1019 detected /        0 sextracted
# > Line: 2320  Objects:     1028 detected /        0 sextracted
# > Line: 2336  Objects:     1037 detected /        0 sextracted
# > Line: 2352  Objects:     1044 detected /        0 sextracted
# > Line: 2368  Objects:     1052 detected /        0 sextracted
# > Line: 2384  Objects:     1057 detected /        0 sextracted
# > Line: 2400  Objects:     1062 detected /        0 sextracted
# > Line: 2416  Objects:     1067 detected /        0 sextracted
# > Line: 2432  Objects:     1077 detected /        0 sextracted
# > Line: 2448  Objects:     1082 detected /        0 sextracted
# > Line: 2464  Objects:     1092 detected /        0 sextracted
# > Line: 2480  Objects:     1102 detected /        0 sextracted
# > Line: 2496  Objects:     1109 detected /        0 sextracted
# > Line: 2512  Objects:     1117 detected /        0 sextracted
# > Line: 2528  Objects:     1125 detected /        0 sextracted
# > Line: 2544  Objects:     1134 detected /        0 sextracted
# > Line: 2560  Objects:     1138 detected /        0 sextracted
# > Line: 2576  Objects:     1143 detected /        0 sextracted
# > Line: 2592  Objects:     1153 detected /        0 sextracted
# > Line: 2608  Objects:     1157 detected /        0 sextracted
# > Line: 2624  Objects:     1159 detected /        0 sextracted
# > Line: 2640  Objects:     1164 detected /        0 sextracted
# > Line: 2656  Objects:     1173 detected /        0 sextracted
# > Line: 2672  Objects:     1184 detected /        0 sextracted
# > Line: 2688  Objects:     1185 detected /        0 sextracted
# > Line: 2704  Objects:     1191 detected /        0 sextracted
# > Line: 2720  Objects:     1197 detected /        0 sextracted
# > Line: 2736  Objects:     1199 detected /        0 sextracted
# > Line: 2752  Objects:     1206 detected /        0 sextracted
# > Line: 2768  Objects:     1214 detected /        0 sextracted
# > Line: 2784  Objects:     1222 detected /        0 sextracted
# > Line: 2800  Objects:     1232 detected /        0 sextracted
# > Line: 2816  Objects:     1237 detected /        0 sextracted
# > Line: 2832  Objects:     1247 detected /        0 sextracted
# > Line: 2848  Objects:     1250 detected /        0 sextracted
# > Line: 2864  Objects:     1268 detected /        0 sextracted
# > Line: 2880  Objects:     1274 detected /        0 sextracted
# > Line: 2896  Objects:     1285 detected /        0 sextracted
# > Line: 2912  Objects:     1289 detected /        0 sextracted
# > Line: 2928  Objects:     1300 detected /        0 sextracted
# > Line: 2944  Objects:     1308 detected /        0 sextracted
# > Line: 2960  Objects:     1313 detected /        0 sextracted
# > Line: 2976  Objects:     1319 detected /        0 sextracted
# > Line: 2992  Objects:     1324 detected /        0 sextracted
# Objects: detected 1329     / sextracted 1175
# > Closing files
# >
# > All done (in 1 s)
# >
# ----- SExtractor 2.8.6 started on 2023-09-08 at 13:21:48 with 8 threads
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for n7265z.resid
# Measuring from: "Unnamed"  / 3000 x 3000 / 0 bits FLOATING POINT data
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   40
# > Setting up background map at line:   80
# > Setting up background map at line:  120
# > Setting up background map at line:  160
# > Setting up background map at line:  200
# > Setting up background map at line:  240
# > Setting up background map at line:  280
# > Setting up background map at line:  320
# > Setting up background map at line:  360
# > Setting up background map at line:  400
# > Setting up background map at line:  440
# > Setting up background map at line:  480
# > Setting up background map at line:  520
# > Setting up background map at line:  560
# > Setting up background map at line:  600
# > Setting up background map at line:  640
# > Setting up background map at line:  680
# > Setting up background map at line:  720
# > Setting up background map at line:  760
# > Setting up background map at line:  800
# > Setting up background map at line:  840
# > Setting up background map at line:  880
# > Setting up background map at line:  920
# > Setting up background map at line:  960
# > Setting up background map at line: 1000
# > Setting up background map at line: 1040
# > Setting up background map at line: 1080
# > Setting up background map at line: 1120
# > Setting up background map at line: 1160
# > Setting up background map at line: 1200
# > Setting up background map at line: 1240
# > Setting up background map at line: 1280
# > Setting up background map at line: 1320
# > Setting up background map at line: 1360
# > Setting up background map at line: 1400
# > Setting up background map at line: 1440
# > Setting up background map at line: 1480
# > Setting up background map at line: 1520
# > Setting up background map at line: 1560
# > Setting up background map at line: 1600
# > Setting up background map at line: 1640
# > Setting up background map at line: 1680
# > Setting up background map at line: 1720
# > Setting up background map at line: 1760
# > Setting up background map at line: 1800
# > Setting up background map at line: 1840
# > Setting up background map at line: 1880
# > Setting up background map at line: 1920
# > Setting up background map at line: 1960
# > Setting up background map at line: 2000
# > Setting up background map at line: 2040
# > Setting up background map at line: 2080
# > Setting up background map at line: 2120
# > Setting up background map at line: 2160
# > Setting up background map at line: 2200
# > Setting up background map at line: 2240
# > Setting up background map at line: 2280
# > Setting up background map at line: 2320
# > Setting up background map at line: 2360
# > Setting up background map at line: 2400
# > Setting up background map at line: 2440
# > Setting up background map at line: 2480
# > Setting up background map at line: 2520
# > Setting up background map at line: 2560
# > Setting up background map at line: 2600
# > Setting up background map at line: 2640
# > Setting up background map at line: 2680
# > Setting up background map at line: 2720
# > Setting up background map at line: 2760
# > Setting up background map at line: 2800
# > Setting up background map at line: 2840
# > Setting up background map at line: 2880
# > Setting up background map at line: 2920
# > Setting up background map at line: 2960
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: -16.4399   RMS: 211.544    / Threshold: 423.087
# > Scanning image
# > Line:   16  Objects:        5 detected /        0 sextracted
# > Line:   32  Objects:       21 detected /        0 sextracted
# > Line:   48  Objects:       34 detected /        0 sextracted
# > Line:   64  Objects:       43 detected /        0 sextracted
# > Line:   80  Objects:       58 detected /        0 sextracted
# > Line:   96  Objects:       72 detected /        0 sextracted
# > Line:  112  Objects:       82 detected /        0 sextracted
# > Line:  128  Objects:       92 detected /        0 sextracted
# > Line:  144  Objects:      104 detected /        0 sextracted
# > Line:  160  Objects:      117 detected /        0 sextracted
# > Line:  176  Objects:      126 detected /        0 sextracted
# > Line:  192  Objects:      135 detected /        0 sextracted
# > Line:  208  Objects:      148 detected /        0 sextracted
# > Line:  224  Objects:      162 detected /        0 sextracted
# > Line:  240  Objects:      174 detected /        0 sextracted
# > Line:  256  Objects:      191 detected /        0 sextracted
# > Line:  272  Objects:      203 detected /        0 sextracted
# > Line:  288  Objects:      211 detected /        0 sextracted
# > Line:  304  Objects:      219 detected /        0 sextracted
# > Line:  320  Objects:      230 detected /        0 sextracted
# > Line:  336  Objects:      245 detected /        0 sextracted
# > Line:  352  Objects:      258 detected /        0 sextracted
# > Line:  368  Objects:      268 detected /        0 sextracted
# > Line:  384  Objects:      275 detected /        0 sextracted
# > Line:  400  Objects:      287 detected /        0 sextracted
# > Line:  416  Objects:      297 detected /        0 sextracted
# > Line:  432  Objects:      303 detected /        0 sextracted
# > Line:  448  Objects:      319 detected /        0 sextracted
# > Line:  464  Objects:      334 detected /        0 sextracted
# > Line:  480  Objects:      343 detected /        0 sextracted
# > Line:  496  Objects:      359 detected /        0 sextracted
# > Line:  512  Objects:      368 detected /        0 sextracted
# > Line:  528  Objects:      375 detected /        0 sextracted
# > Line:  544  Objects:      381 detected /        0 sextracted
# > Line:  560  Objects:      395 detected /        0 sextracted
# > Line:  576  Objects:      411 detected /        0 sextracted
# > Line:  592  Objects:      421 detected /        0 sextracted
# > Line:  608  Objects:      427 detected /        0 sextracted
# > Line:  624  Objects:      436 detected /        0 sextracted
# > Line:  640  Objects:      449 detected /        0 sextracted
# > Line:  656  Objects:      461 detected /        0 sextracted
# > Line:  672  Objects:      470 detected /        0 sextracted
# > Line:  688  Objects:      477 detected /        0 sextracted
# > Line:  704  Objects:      493 detected /        0 sextracted
# > Line:  720  Objects:      502 detected /        0 sextracted
# > Line:  736  Objects:      515 detected /        0 sextracted
# > Line:  752  Objects:      523 detected /        0 sextracted
# > Line:  768  Objects:      534 detected /        0 sextracted
# > Line:  784  Objects:      542 detected /        0 sextracted
# > Line:  800  Objects:      549 detected /        0 sextracted
# > Line:  816  Objects:      561 detected /        0 sextracted
# > Line:  832  Objects:      568 detected /        0 sextracted
# > Line:  848  Objects:      577 detected /        0 sextracted
# > Line:  864  Objects:      587 detected /        0 sextracted
# > Line:  880  Objects:      593 detected /        0 sextracted
# > Line:  896  Objects:      603 detected /        0 sextracted
# > Line:  912  Objects:      618 detected /        0 sextracted
# > Line:  928  Objects:      627 detected /        0 sextracted
# > Line:  944  Objects:      637 detected /        0 sextracted
# > Line:  960  Objects:      648 detected /        0 sextracted
# > Line:  976  Objects:      659 detected /        0 sextracted
# > Line:  992  Objects:      671 detected /        0 sextracted
# > Line: 1008  Objects:      680 detected /        0 sextracted
# > Line: 1024  Objects:      699 detected /        0 sextracted
# > Line: 1040  Objects:      718 detected /        0 sextracted
# > Line: 1056  Objects:      733 detected /        0 sextracted
# > Line: 1072  Objects:      743 detected /        0 sextracted
# > Line: 1088  Objects:      760 detected /        0 sextracted
# > Line: 1104  Objects:      782 detected /        0 sextracted
# > Line: 1120  Objects:      804 detected /        0 sextracted
# > Line: 1136  Objects:      817 detected /        0 sextracted
# > Line: 1152  Objects:      830 detected /        0 sextracted
# > Line: 1168  Objects:      839 detected /        0 sextracted
# > Line: 1184  Objects:      848 detected /        0 sextracted
# > Line: 1200  Objects:      866 detected /        0 sextracted
# > Line: 1216  Objects:      882 detected /        0 sextracted
# > Line: 1232  Objects:      899 detected /        0 sextracted
# > Line: 1248  Objects:      914 detected /        0 sextracted
# > Line: 1264  Objects:      937 detected /        0 sextracted
# > Line: 1280  Objects:      960 detected /        0 sextracted
# > Line: 1296  Objects:      974 detected /        0 sextracted
# > Line: 1312  Objects:      992 detected /        0 sextracted
# > Line: 1328  Objects:     1007 detected /        0 sextracted
# > Line: 1344  Objects:     1018 detected /        0 sextracted
# > Line: 1360  Objects:     1035 detected /        0 sextracted
# > Line: 1376  Objects:     1050 detected /        0 sextracted
# > Line: 1392  Objects:     1066 detected /        0 sextracted
# > Line: 1408  Objects:     1077 detected /        0 sextracted
# > Line: 1424  Objects:     1086 detected /        0 sextracted
# > Line: 1440  Objects:     1090 detected /        0 sextracted
# > Line: 1456  Objects:     1097 detected /        0 sextracted
# > Line: 1472  Objects:     1122 detected /        0 sextracted
# > Line: 1488  Objects:     1138 detected /        0 sextracted
# > Line: 1504  Objects:     1153 detected /        0 sextracted
# > Line: 1520  Objects:     1168 detected /        0 sextracted
# > Line: 1536  Objects:     1192 detected /        0 sextracted
# > Line: 1552  Objects:     1209 detected /        0 sextracted
# > Line: 1568  Objects:     1222 detected /        0 sextracted
# > Line: 1584  Objects:     1244 detected /        0 sextracted
# > Line: 1600  Objects:     1254 detected /        0 sextracted
# > Line: 1616  Objects:     1272 detected /        0 sextracted
# > Line: 1632  Objects:     1294 detected /        0 sextracted
# > Line: 1648  Objects:     1311 detected /        0 sextracted
# > Line: 1664  Objects:     1323 detected /        0 sextracted
# > Line: 1680  Objects:     1333 detected /        0 sextracted
# > Line: 1696  Objects:     1344 detected /        0 sextracted
# > Line: 1712  Objects:     1358 detected /        0 sextracted
# > Line: 1728  Objects:     1367 detected /        0 sextracted
# > Line: 1744  Objects:     1376 detected /        0 sextracted
# > Line: 1760  Objects:     1385 detected /        0 sextracted
# > Line: 1776  Objects:     1401 detected /        0 sextracted
# > Line: 1792  Objects:     1416 detected /        0 sextracted
# > Line: 1808  Objects:     1426 detected /        0 sextracted
# > Line: 1824  Objects:     1431 detected /        0 sextracted
# > Line: 1840  Objects:     1442 detected /        0 sextracted
# > Line: 1856  Objects:     1456 detected /        0 sextracted
# > Line: 1872  Objects:     1465 detected /        0 sextracted
# > Line: 1888  Objects:     1481 detected /        0 sextracted
# > Line: 1904  Objects:     1486 detected /        0 sextracted
# > Line: 1920  Objects:     1496 detected /        0 sextracted
# > Line: 1936  Objects:     1506 detected /        0 sextracted
# > Line: 1952  Objects:     1517 detected /        0 sextracted
# > Line: 1968  Objects:     1527 detected /        0 sextracted
# > Line: 1984  Objects:     1539 detected /        0 sextracted
# > Line: 2000  Objects:     1556 detected /        0 sextracted
# > Line: 2016  Objects:     1565 detected /        0 sextracted
# > Line: 2032  Objects:     1575 detected /        0 sextracted
# > Line: 2048  Objects:     1591 detected /        0 sextracted
# > Line: 2064  Objects:     1601 detected /        0 sextracted
# > Line: 2080  Objects:     1608 detected /        0 sextracted
# > Line: 2096  Objects:     1612 detected /        0 sextracted
# > Line: 2112  Objects:     1624 detected /        0 sextracted
# > Line: 2128  Objects:     1636 detected /        0 sextracted
# > Line: 2144  Objects:     1645 detected /        0 sextracted
# > Line: 2160  Objects:     1648 detected /        0 sextracted
# > Line: 2176  Objects:     1658 detected /        0 sextracted
# > Line: 2192  Objects:     1677 detected /        0 sextracted
# > Line: 2208  Objects:     1688 detected /        0 sextracted
# > Line: 2224  Objects:     1701 detected /        0 sextracted
# > Line: 2240  Objects:     1706 detected /        0 sextracted
# > Line: 2256  Objects:     1717 detected /        0 sextracted
# > Line: 2272  Objects:     1731 detected /        0 sextracted
# > Line: 2288  Objects:     1742 detected /        0 sextracted
# > Line: 2304  Objects:     1750 detected /        0 sextracted
# > Line: 2320  Objects:     1763 detected /        0 sextracted
# > Line: 2336  Objects:     1774 detected /        0 sextracted
# > Line: 2352  Objects:     1785 detected /        0 sextracted
# > Line: 2368  Objects:     1795 detected /        0 sextracted
# > Line: 2384  Objects:     1809 detected /        0 sextracted
# > Line: 2400  Objects:     1816 detected /        0 sextracted
# > Line: 2416  Objects:     1827 detected /        0 sextracted
# > Line: 2432  Objects:     1840 detected /        0 sextracted
# > Line: 2448  Objects:     1853 detected /        0 sextracted
# > Line: 2464  Objects:     1870 detected /        0 sextracted
# > Line: 2480  Objects:     1882 detected /        0 sextracted
# > Line: 2496  Objects:     1896 detected /        0 sextracted
# > Line: 2512  Objects:     1905 detected /        0 sextracted
# > Line: 2528  Objects:     1915 detected /        0 sextracted
# > Line: 2544  Objects:     1928 detected /        0 sextracted
# > Line: 2560  Objects:     1934 detected /        0 sextracted
# > Line: 2576  Objects:     1943 detected /        0 sextracted
# > Line: 2592  Objects:     1962 detected /        0 sextracted
# > Line: 2608  Objects:     1968 detected /        0 sextracted
# > Line: 2624  Objects:     1976 detected /        0 sextracted
# > Line: 2640  Objects:     1987 detected /        0 sextracted
# > Line: 2656  Objects:     1997 detected /        0 sextracted
# > Line: 2672  Objects:     2015 detected /        0 sextracted
# > Line: 2688  Objects:     2022 detected /        0 sextracted
# > Line: 2704  Objects:     2031 detected /        0 sextracted
# > Line: 2720  Objects:     2043 detected /        0 sextracted
# > Line: 2736  Objects:     2056 detected /        0 sextracted
# > Line: 2752  Objects:     2068 detected /        0 sextracted
# > Line: 2768  Objects:     2082 detected /        0 sextracted
# > Line: 2784  Objects:     2086 detected /        0 sextracted
# > Line: 2800  Objects:     2095 detected /        0 sextracted
# > Line: 2816  Objects:     2105 detected /        0 sextracted
# > Line: 2832  Objects:     2113 detected /        0 sextracted
# > Line: 2848  Objects:     2119 detected /        0 sextracted
# > Line: 2864  Objects:     2135 detected /        0 sextracted
# > Line: 2880  Objects:     2146 detected /        0 sextracted
# > Line: 2896  Objects:     2158 detected /        0 sextracted
# > Line: 2912  Objects:     2168 detected /        0 sextracted
# > Line: 2928  Objects:     2181 detected /        0 sextracted
# > Line: 2944  Objects:     2191 detected /        0 sextracted
# > Line: 2960  Objects:     2199 detected /        0 sextracted
# > Line: 2976  Objects:     2213 detected /        0 sextracted
# > Line: 2992  Objects:     2221 detected /        0 sextracted
# Objects: detected 2229     / sextracted 2044
# > Closing files
# >
# > All done (in 1 s)

# %%
# Multiply mask by line mask, if it exists
monsta_script = """
    rd 1 '"""+PS_mask+"""'
    rd 2 '"""+PS_lines+"""'
    mi 1 2
    wd 1 '"""+PS_mask+"""' bitmap
"""

if os.path.exists(PS_lines):
    run_monsta(monsta_script, 'monsta.pro', 'monsta.log')

# %%
# Multiply residual images by mask for display
monsta_script = """
    rd 1 '"""+outFolder+name+"""g.resid'
    rd 2 '"""+outFolder+name+"""z.resid'
    rd 10 '"""+PS_mask+"""' bitmap 
    mi 1 10
    mi 2 10
    wd 1 '"""+outFolder+name+"""g.resid'
    wd 2 '"""+outFolder+name+"""z.resid'
    rd 10 '"""+PS_circlemask+"""'
    ac 1 500.
    ac 2 500.
    mi 1 10
    mi 2 10
    box 1 nc=550 nr=550 cc=1500 cr=1500
    wind 1 box=1
    wind 2 box=1
    wd 1 '"""+outFolder+name+"""g.zoom.resid'
    wd 2 '"""+outFolder+name+"""z.zoom.resid'
"""
run_monsta(monsta_script, 'monsta.pro', 'monsta.log')
# Out:
# 'OK'

# %%
# Source Extractor test cell - uncomment to see if SExtractor is working.
# ! sex {sestring_g}

# %%
#PS_newmask = outFolder+name+".mask"

plt.figure(figsize=(15,20))

plt.subplot(321)
ax = plt.gca()
tv(outFolder+name+'g.nonan',ax=ax, options='sqrt')
ax.set_title(name + " (g-band)", fontsize=14)

plt.subplot(322)
ax = plt.gca()
tv(outFolder+name+'z.nonan',ax=ax, options='sqrt')
ax.set_title(name + " (z-band)", fontsize=14)

plt.subplot(325)
ax = plt.gca()
tv(PS_mask,ax=ax)
ax.set_title("Mask", fontsize=14)

plt.subplot(323)
ax = plt.gca()
tv(outFolder+name+"g.zoom.resid",ax=ax, options='')
ax.set_title(name + " Residual zoom (g)", fontsize=14)

plt.subplot(324)
ax = plt.gca()
tv(outFolder+name+"z.zoom.resid",ax=ax, options='')
ax.set_title(name + " Residual zoom (z)", fontsize=14)

plt.subplot(326)
ax = plt.gca()
tv(PS_skymask,ax=ax)
ax.set_title("Sky Mask", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Sky Mask')

# %% [markdown]
# ## Saving the color information

# %%
import json

def save_colors(monsta_log="monsta.log"):
    
    outdict = {}
    radii = []
    outdict["Radii"] = radii

    with open("monsta.log", "r") as f:
        lines = f.readlines()

    for l in lines:
        l0 = l.strip()
        l00 = l0.split()

        if l00:

            if "Unity" in l0:
                #radii.append({"Unity": float(l00[2]), "Average_radius": float(l00[6])})
                radii.append({"Average_radius": float(l00[6])})

                # radii.append({"Average_radius": float(100[6])})
                
            if "MED" in l00[0] or "AV" in l00[0]:
                outdict[l00[0]] = float(l00[2])

            if "extinction" in l0:
                outdict["name"] = l00[0]

    json_name = outFolder+name+"_color_ps_gz.json"
    with open(json_name, 'w') as file:
        json_string = json.dumps(outdict, default=lambda o: o.__dict__, sort_keys=True, indent=2)
        file.write(json_string)

        print("Colors are stored in: ", json_name)

    return json_name

# %% [markdown]
# ## Measure $(g-z)$

# %%
monsta_script = """
    string name '"""+name+"""'

    ! make the g-z color map
    rd 1 '"""+g_fits+"""'
    rd 2 '"""+z_fits+"""'
    clip 1 nan=0
    clip 2 nan=0
    dc 1 """+str(gexp)+"""
    dc 2 """+str(zexp)+"""
    cop 3 1
    cop 4 2
    rd 5 '"""+PS_skymask+"""'
    ! read the input PS mask; if it's not there, read the one that the notebook just made.
    rd 6 '"""+PS_mask+"""'
    mi 5 6
    mi 3 5
    mi 4 5
    cop 10 4
    ! sky values
    abx 3 all median median=skyg silent
    abx 4 all median median=skyz silent
    sc 1 skyg
    sc 2 skyz
    log 1
    mc 1 -2.5
    sc 1 """+str(gext)+"""
    log 2
    mc 2 -2.5
    sc 2 """+str(zext)+"""
    cop 3 1
    si 3 2
    wd 3 '"""+outFolder+name+"""gz.clr'
    cop 10 3
    mi 10 6
    ac 10 2
    rd 7 '"""+PS_circlemask+"""'
    mi 10 7
    box 1 nc=550 nr=550 cc=1500 cr=1500
    wind 10 box=1
    wd 10 '"""+outFolder+name+"""gz.zoom.clr'
    close 7
    
    ! measure the (g-z) values
    cop 1 3
    mi 1 6
    close 6
    open 2 nr=512 nc=512
    fluc 2 1 mask x0=1500 y0=1500 r0=15.9 r1=31.8 a0=0 a1=360 ! c0
    abx 2 all median=median medrms=rms silent
    ! typ median,rms
    set max=2*rms+median
    set min=-2*rms+median
    ! typ min,max
    clip 1 max=max vmax=0 min=min vmin=0
    close 2
    open 3 nr=512 nc=512
    fluc 3 1 mask x0=1500 y0=1500 r0=15.9 r1=31.8 a0=0 a1=360 ! c0
    open 4 nr=512 nc=512
    fluc 4 1 mask x0=1500 y0=1500 r0=31.8 r1=63.5 a0=0 a1=360 ! c1
    open 5 nr=512 nc=512
    fluc 5 1 mask x0=1500 y0=1500 r0=63.5 r1=127 a0=0 a1=360 ! c2
    open 6 nr=512 nc=512
    fluc 6 1 mask x0=1500 y0=1500 r0=127 r1=254 a0=0 a1=90 ! nw
    open 7 nr=512 nc=512
    fluc 7 1 mask x0=1500 y0=1500 r0=127 r1=254 a0=90 a1=180 ! sw
    open 8 nr=512 nc=512
    fluc 8 1 mask x0=1500 y0=1500 r0=127 r1=254 a0=180 a1=270 ! se
    open 9 nr=512 nc=512
    fluc 9 1 mask x0=1500 y0=1500 r0=127 r1=254 a0=270 a1=360 ! ne

    ! medians
    ! abx 2 all median median=medcc medrms=medccrms silent
    abx 3 all median median=medc0 medrms=medc0rms silent
    abx 4 all median median=medc1 medrms=medc1rms silent
    abx 5 all median median=medc2 medrms=medc2rms silent
    abx 6 all median median=mednw medrms=mednwrms silent
    abx 7 all median median=medsw medrms=medswrms silent
    abx 8 all median median=medse medrms=medserms silent
    abx 9 all median median=medne medrms=mednerms silent

    ! do in the same regions as we do SBF measurements
    set medc5=mednw+medsw+medse+medne/4
    printf ' '
    typ skyg,skyz
    printf ' '
     printf '{name} median (g-z) extinction corrected'
    ! printf ' '
     typ medc0,medc1,medc2,medc5
    ! printf '{name} (g-z) rms values'
    ! typ medc0rms,medc1rms,medc2rms,mednerms

    ! averages
    ! abx 2 all mean=avcc rms=avccrms silent
    abx 3 all mean=avc0 rms=avc0rms silent
    abx 4 all mean=avc1 rms=avc1rms silent
    abx 5 all mean=avc2 rms=avc2rms silent
    abx 6 all mean=avnw rms=avnwrms silent
    abx 7 all mean=avsw rms=avswrms silent
    abx 8 all mean=avse rms=avserms silent
    abx 9 all mean=avne rms=avnerms silent
    set avc5=avnw+avsw+avse+avne/4
    printf ' '
    printf '{name} average (g-z) extinction corrected'
    ! printf ' '
    typ avc0,avc1,avc2,avc5
    ! printf '{name} (g-z) rms values' 
    ! typ avc0rms,avc1rms,avc2rms,avnerms
"""

run_monsta(monsta_script, 'monsta.pro', 'monsta.log')
#!cat monsta.log

ax = plt.gca()
tv(outFolder+name+"gz.zoom.clr",ax=ax, options='0 5')
ax.set_title(name + " (g-z) color map", fontsize=14)

json_name = save_colors(monsta_log="monsta.log")

################
# !rm monsta.log
# !rm monsta.pro
# !rm tv.jpg
# Out:
# Colors are stored in:  /home/ehsan/PanStarrs/Jan/HI/augment/SBF/wfc3-16262/PS/n7265/PS_Outputs_n7265/n7265_color_ps_gz.json
# rm: cannot remove 'tv.jpg': No such file or directory

# %%
#!cat monsta.log

# %%
# clean up temporary display images
temp = outFolder+name+'*.zoom.*'
# !rm {temp}
temp = outFolder+name+'*.nonan'
# !rm {temp}

# %% [markdown]
# ## Color Results
#
# ### The content of the color json file:

# %%
# !cat {json_name}
# Out:
# {
#   "AVC0": 1.3335524797439575,
#   "AVC1": 1.3273181915283203,
#   "AVC2": 1.3350226879119873,
#   "AVC5": 1.3354635536670685,
#   "MEDC0": 1.3359215259552002,
#   "MEDC1": 1.3269541263580322,
#   "MEDC2": 1.3352525234222412,
#   "MEDC5": 1.3339723646640778,
#   "Radii": [
#     {
#       "Average_radius": 24.7
#     },
#     {
#       "Average_radius": 24.6
#     },
#     {
#       "Average_radius": 48.3
#     },
#     {
#       "Average_radius": 93.0
#     },
#     {
#       "Average_radius": 178.9
#     },
#     {
#       "Average_radius": 182.7
#     },
#     {
#       "Average_radius": 184.4
#     },
#     {
#       "Average_radius": 184.7
#     }
#   ],
#   "name": "n7265"
# }
