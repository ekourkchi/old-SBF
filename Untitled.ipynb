# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1442">Loading BokehJS ...</span>
#     </div>

# %%
p1 = figure(plot_width=250, plot_height=250)
r1 = p1.circle([1,2,3], [4,5,6], size=20)

p2 = figure(plot_width=250, plot_height=250)
r2 = p2.circle([1,2,3], [4,5,6], size=10)

t = show(row(p1,p2), notebook_handle=True)
# Out:
#   <div class="bk-root" id="c21c24f0-9911-4d1f-9d2e-8cc7719cb4b8" data-root-id="1517"></div>

# %%
p1 = figure(plot_width=250, plot_height=250)
r1 = p1.circle([1,2,3], [4,5,6], size=20)

p2 = figure(plot_width=250, plot_height=250)
r2 = p2.circle([1,2,3], [4,5,6], size=10)

t = show(row(p1,p2), notebook_handle=True)
# Out:
#   <div class="bk-root" id="7cdae3f4-a51b-43a8-9c14-cf173931a141" data-root-id="1769"></div>

# %%
p1 = figure(plot_width=250, plot_height=250)
r1 = p1.circle([1,2,3], [4,5,6], size=20)

p2 = figure(plot_width=250, plot_height=250)
r2 = p2.circle([1,2,3], [4,5,6], size=10)

t = show(row(p1,p2), notebook_handle=True)
# Out:
#   <div class="bk-root" id="7fdb629b-587d-4aeb-83f7-76f0f0c5362f" data-root-id="2043"></div>
